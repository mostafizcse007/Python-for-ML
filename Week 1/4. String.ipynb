# %%
string = 'a quick brown fox jump quick over a lazy dog'
print(string.lower())
print(string.upper())
print(string.capitalize())
print(string.title())
print(string.swapcase())
if 'quick' in string:
    print("Available")
else:
    print("Not present")

# %% [markdown]
# ###### Substring index

# %%
first_index = string.find('quick')
last_index = string.rfind('quick')
print(first_index,last_index)
print(string.count('quick'))
print(string.replace('quick','fast'))
print(string)

new_string = string.split()
print('🐸'.join(new_string))

# %%
val = '       aaa     '
print(val.split())
