# %%
lst = list(range(6,0,-1))
lst

# %%
lst.insert(1,100)
lst.sort()
lst.sort(reverse=True)
lst.extend([300,400])
lst

# %%
arr = [1,2,34,5,100,100,100,100]
while 100 in arr:
    arr.remove(100)
    print('removed')

# %%
arr

# %%
vals = [1,2,3,4,5]
while len(vals):
    vals.pop(0)
    print('removed')
vals

# %%
word = ['a','b','c','d','e']

print(word[1:4][::-2])
# Out:
# ['d', 'b']
